# %%
from transformer_lens import HookedTransformer
import torch

# %%
model = HookedTransformer.from_pretrained("gemma-2b")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Fetching 2 files:   0%|          | 0/2 [02:40<?, ?it/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = HookedTransformer.from_pretrained("gemma-2b")
#
# File ~/uncertainty/.venv/lib/python3.13/site-packages/transformer_lens/HookedTransformer.py:1370, in HookedTransformer.from_pretrained(cls, model_name, fold_ln, center_writing_weights, center_unembed, refactor_factored_attn_matrices, checkpoint_index, checkpoint_value, hf_model, device, n_devices, tokenizer, move_to_device, fold_value_biases, default_prepend_bos, default_padding_side, dtype, first_n_layers, **from_pretrained_kwargs)
#    1366     center_unembed = False
#    1368 # Get the state dict of the model (ie a mapping of parameter names to tensors), processed to
# ...

# %%
hooked_model = HookedTransformer.from_pretrained('gpt2') # check out list of supported model here:
