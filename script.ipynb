# %%
import torch
# Out:
# Running cells with 'uncertainty (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/shifenghong/uncertainty/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
